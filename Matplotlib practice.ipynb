# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
linear = np.arange(8)
y1 = np.arange(8)
y2 = np.square(linear)

# %%
plt.figure()
ax1 = plt.subplot(121)
plt.plot(linear,y1,'-om')
ax = plt.subplot(122,sharey =ax1)
ax.plot(linear,y2,':xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1.plot(linear,y2,'-.')

# %%
ax1.clear()

# %%
ax1.fill_between(x = linear,y1 = y1,y2 = y2,where = y2>=y1)

# %%
plt.figure()
plt.plot(linear,linear,'-om',alpha = 0.5)
plt.plot(linear,y2,':xb',alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = plt.gca().xaxis

# %%
x.set_ticklabels(['']*8)
# Out:
# <ipython-input-10-94c2a1f9569c>:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   x.set_ticklabels(['']*8)
# [Text(-1.0, 0, ''),
#  Text(0.0, 0, ''),
#  Text(1.0, 0, ''),
#  Text(2.0, 0, ''),
#  Text(3.0, 0, ''),
#  Text(4.0, 0, ''),
#  Text(5.0, 0, ''),
#  Text(6.0, 0, ''),
#  Text(7.0, 0, ''),
#  Text(8.0, 0, '')]

# %%
x.set_ticklabels(np.arange('2017-01-01', '2017-01-09', dtype='datetime64[D]'))
# Out:
# <ipython-input-11-f42a95c72570>:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   x.set_ticklabels(np.arange('2017-01-01', '2017-01-09', dtype='datetime64[D]'))
# [Text(-1.0, 0, '2017-01-01'),
#  Text(0.0, 0, '2017-01-02'),
#  Text(1.0, 0, '2017-01-03'),
#  Text(2.0, 0, '2017-01-04'),
#  Text(3.0, 0, '2017-01-05'),
#  Text(4.0, 0, '2017-01-06'),
#  Text(5.0, 0, '2017-01-07'),
#  Text(6.0, 0, '2017-01-08'),
#  Text(7.0, 0, ''),
#  Text(8.0, 0, '')]

# %%
for i in x.get_ticklabels():
    i.set_rotation(45)

# %%
plt.tight_layout()
