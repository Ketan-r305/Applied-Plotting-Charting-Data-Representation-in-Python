# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

# %%
plt.figure()
plt.subplot(221)
plt.hist(x1,bins = 20,density = True,color = 'r')
plt.subplot(222)
plt.hist(x2,bins = 20,normed = True,color = 'm')
plt.subplot(223)
plt.hist(x3,bins = 20,normed = True,color = 'y')
plt.subplot(224)
plt.hist(x4,bins = 20,normed = True,color = 'k')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-3-930865e90f86>:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   plt.hist(x2,bins = 20,normed = True,color = 'm')
# <ipython-input-3-930865e90f86>:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   plt.hist(x3,bins = 20,normed = True,color = 'y')
# <ipython-input-3-930865e90f86>:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   plt.hist(x4,bins = 20,normed = True,color = 'k')

# %%
import matplotlib.animation as animation

# %%
'''
# create the function that will do the plotting, where curr is the current frame
def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == 1000: 
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-6.5, 1, 0.5)
    plt.hist(x1[:curr], bins=bins,normed = True)
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
'''
# Out:
# "\n# create the function that will do the plotting, where curr is the current frame\ndef update(curr):\n    # check if animation is at the last frame, and if so, stop the animation a\n    if curr == 1000: \n        a.event_source.stop()\n    plt.cla()\n    bins = np.arange(-6.5, 1, 0.5)\n    plt.hist(x1[:curr], bins=bins,normed = True)\n    plt.gca().set_title('Sampling the Normal Distribution')\n    plt.gca().set_ylabel('Frequency')\n    plt.gca().set_xlabel('Value')\n    \n"

# %%
'''
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=1)
'''
# Out:
# '\nfig = plt.figure()\na = animation.FuncAnimation(fig, update, interval=1)\n'

# %%
animation.FuncAnimation??

# %%
plt.cla??

# %%
def update_1(curr):
    
    if curr == 500:
        a.event_source.stop()
    plt.subplot(221)
    plt.cla()
    bins_1 = np.arange(-6.,1.,0.5)
    plt.hist(x1[:curr],bins = bins_1,color = 'y',density = True,alpha = 0.5)
    plt.gca().set_title('Sampling Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.subplot(222)
    plt.cla()
    bins_2 = np.arange(0.,12.,0.5)
    plt.hist(x2[:curr],bins = bins_2,color = 'm',density = True,alpha = 0.5)
    plt.gca().set_title('Sampling Gamma Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.subplot(223)
    plt.cla()
    bins_3 = np.arange(5.,15.,0.5)
    plt.hist(x3[:curr],bins = bins_3,color = 'r',density = True,alpha = 0.5)
    plt.gca().set_title('Sampling Exponential Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.subplot(224)
    plt.cla()
    bins_4 = np.arange(12.,22.,0.5)
    plt.hist(x1[:curr],bins = bins_1,color = 'b',density = True,alpha = 0.5)
    plt.gca().set_title('Sampling Uniform Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.tight_layout()

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update_1, interval=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
